# %%
# 회귀모형 
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd 
import seaborn as sns 

# 쓸데없는 알림 방지
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

import itertools

#통계적 모형
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor 

#머신러닝
from sklearn import datasets
from sklearn import metrics

from sklearn.linear_model import Ridge, Lasso, LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_log_error, mean_squared_error, r2_score, mean_absolute_error #연속형일때 사용하는 경우 
from sklearn.metrics import accuracy_score, roc_auc_score, roc_curve, confusion_matrix #범주형(분류모델)

# %%
titanic_train= pd.read_csv('C:/Users/scien/Videos/titanic/titanic_train.csv')
titanic_test = pd.read_csv('C:/Users/scien/Videos/titanic/titanic_test.csv')
titanic_original = pd.read_csv('C:/Users/scien/Videos/titanic/titanic_original.csv')

# %%
titanic_test.Name.unique().size
# Out:
# 418

# %%
titanic_original.name.unique().size
# Out:
# 1307

# %%
titanic_original.info()

# 이름의 유니크는 1307개 이나 네임컬럼은 1309개
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
# 따라서 오리지널 이름에 중복되는 내용을 확인하는 duplicated 사용 keep=False로 해줘야
# 중복된 모든 값을 보여줌 
titanic_original.loc[titanic_original.duplicated(['name'], keep=False)]
# Out:
#      pclass  survived                  name     sex   age  sibsp  parch  \
# 725       3         1  Connolly, Miss. Kate  female    22      0      0
# 726       3         0  Connolly, Miss. Kate  female    30      0      0
# 924       3         0      Kelly, Mr. James    male  34.5      0      0
# 925       3         0      Kelly, Mr. James    male    44      0      0
#
#      ticket    fare cabin embarked boat body home.dest
# 725  370373    7.75     ?        Q   13    ?   Ireland
# 726  330972  7.6292     ?        Q    ?    ?   Ireland
# 924  330911  7.8292     ?        Q    ?   70         ?
# 925  363592    8.05     ?        S    ?    ?         ?

# %% [markdown]
# 테스트 셋은 생존 여부가 없고
# 오리지널 셋은 페신저 아이디가 없다. (=> 적합해주기 위해서 테스셋의 이름 필드를 기준으로 합치고자 하는데 다행히도 테스트셋의 이름은 겹치는 것이 없다.)

# %% [markdown]
# 테스트와 트레인셋 각각 중복되는 이름이 따로 따로 저장되어 있다.

# %%
titanic_train.loc[titanic_train['Name'] == 'Connolly, Miss. Kate'][['Name','Age']]
# Out:
#                      Name   Age
# 289  Connolly, Miss. Kate  22.0

# %%
titanic_train.loc[titanic_train['Name'] == 'Kelly, Mr. James']['Name']
# Out:
# 696    Kelly, Mr. James
# Name: Name, dtype: object

# %%
titanic_test.loc[titanic_test['Name'] == 'Connolly, Miss. Kate']['Name']
# Out:
# 6    Connolly, Miss. Kate
# Name: Name, dtype: object

# %%
titanic_test.loc[titanic_test['Name'] == 'Kelly, Mr. James']['Name']
# Out:
# 0    Kelly, Mr. James
# Name: Name, dtype: object

# %%
titanic_original.loc[titanic_original.duplicated(['name'], keep='last')]
# Out:
#      pclass  survived                  name     sex   age  sibsp  parch  \
# 725       3         1  Connolly, Miss. Kate  female    22      0      0
# 924       3         0      Kelly, Mr. James    male  34.5      0      0
#
#      ticket    fare cabin embarked boat body home.dest
# 725  370373    7.75     ?        Q   13    ?   Ireland
# 924  330911  7.8292     ?        Q    ?   70         ?

# %% [markdown]
# 중복값 쉽게 삭제 drop_duplicates()
#
# 그러나 지우고 싶은 데이터를 쉽게 지울 수 없으니 직접 지운다.

# %%
drop_idx  = titanic_original.loc[(titanic_original['name'] == 'Connolly, Miss. Kate') & (titanic_original['age'] == '22')].index
titanic_original.drop(drop_idx, inplace=True)

# %%
drop_idx  = titanic_original.loc[(titanic_original['name'] == 'Kelly, Mr. James') & (titanic_original['age'] == '44')].index
titanic_original.drop(drop_idx, inplace=True)

# %% [markdown]
# # 이름이 ")"가 들어 있어서 수정이 필요함.
# - 아무튼 현재 해결이 불가능하기 때문에 (수작업으로 진행해야함)

# %%
# rename 되었기 때문에 오류가 발생하는 것 무시해
titanic_survived = titanic_original[['survived', 'name']]

# %%
titanic_survived.rename(columns = {'survived' : 'Survived', 'name' : 'Name'}, inplace = True)

# %%
titanic_sample = pd.merge(left=titanic_test, right=titanic_survived, on='Name')

# %%
titanic_sample
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 389         1305       3                            Spector, Mr. Woolf
# 390         1306       1                  Oliva y Ocana, Dona. Fermina
# 391         1307       3                  Saether, Mr. Simon Sivertsen
# 392         1308       3                           Ware, Mr. Frederick
# 393         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 389    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 390  female  39.0      0      0            PC 17758  108.9000  C105        C
# 391    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 392    male   NaN      0      0              359309    8.0500   NaN        S
# 393    male   NaN      1      1                2668   22.3583   NaN        C
#
#      Survived
# 0           0
# 1           1
# 2           0
# 3           0
# 4           1
# ..        ...
# 389         0
# 390         1
# 391         0
# 392         0
# 393         1
#
# [394 rows x 12 columns]

# %%
titanic_sample.loc[titanic_sample['Survived'].isna()][['Name']]
# Out:
# Empty DataFrame
# Columns: [Name]
# Index: []

# %%
titanic_original.loc[titanic_original['name'].str.startswith('Assaf Khalil')]
# Out:
#      pclass  survived                                   name     sex age  \
# 647       3         1  Assaf Khalil, Mrs. Mariana ('Miriam')  female  45
#
#      sibsp  parch ticket   fare cabin embarked boat body   home.dest
# 647      0      0   2696  7.225     ?        C    C    ?  Ottawa, ON

# %%
titanic_test.loc[titanic_test['Name'].str.startswith('Assaf Khalil')]
# Out:
#     PassengerId  Pclass                                   Name     Sex   Age  \
# 19          911       3  Assaf Khalil, Mrs. Mariana (Miriam")"  female  45.0
#
#     SibSp  Parch Ticket   Fare Cabin Embarked
# 19      0      0   2696  7.225   NaN        C

# %%
titanic_sample = pd.merge(left=titanic_test, right=titanic_original, on='Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-69e8a4eab760> in <module>
# ----> 1 titanic_sample = pd.merge(left=titanic_test, right=titanic_original, on='Name')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      71     validate=None,
#      72 ) -> "DataFrame":
# ---> 73     op = _MergeOperation(
#      74         left,
#      75         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     625             self.right_join_keys,
#     626             self.join_names,
# --> 627         ) = self._get_merge_keys()
#     628
#     629         # validate the merge keys dtypes. We may need to coerce
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     981                     if not is_rkey(rk):
#     982                         if rk is not None:
# --> 983                             right_keys.append(right._get_label_or_level_values(rk))
#     984                         else:
#     985                             # work-around for merge_asof(right_index=True)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1690             values = self.axes[axis].get_level_values(key)._values
#    1691         else:
# -> 1692             raise KeyError(key)
#    1693
#    1694         # Check for duplicates
#
# KeyError: 'Name'

# %%
titanic_sample
# 결측치가 존재
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 389         1305       3                            Spector, Mr. Woolf
# 390         1306       1                  Oliva y Ocana, Dona. Fermina
# 391         1307       3                  Saether, Mr. Simon Sivertsen
# 392         1308       3                           Ware, Mr. Frederick
# 393         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin  ...  \
# 0      male  34.5      0      0              330911    7.8292   NaN  ...
# 1    female  47.0      1      0              363272    7.0000   NaN  ...
# 2      male  62.0      0      0              240276    9.6875   NaN  ...
# 3      male  27.0      0      0              315154    8.6625   NaN  ...
# 4    female  22.0      1      1             3101298   12.2875   NaN  ...
# ..      ...   ...    ...    ...                 ...       ...   ...  ...
# 389    male   NaN      0      0           A.5. 3236    8.0500   NaN  ...
# 390  female  39.0      0      0            PC 17758  108.9000  C105  ...
# 391    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN  ...
# 392    male   NaN      0      0              359309    8.0500   NaN  ...
# 393    male   NaN      1      1                2668   22.3583   NaN  ...
#
#       age  sibsp  parch              ticket     fare  cabin  embarked boat  \
# 0    34.5      0      0              330911   7.8292      ?         Q    ?
# 1      47      1      0              363272        7      ?         S    ?
# 2      62      0      0              240276   9.6875      ?         Q    ?
# 3      27      0      0              315154   8.6625      ?         S    ?
# 4      22      1      1             3101298  12.2875      ?         S   15
# ..    ...    ...    ...                 ...      ...    ...       ...  ...
# 389     ?      0      0           A.5. 3236     8.05      ?         S    ?
# 390    39      0      0            PC 17758    108.9   C105         C    8
# 391  38.5      0      0  SOTON/O.Q. 3101262     7.25      ?         S    ?
# 392     ?      0      0              359309     8.05      ?         S    ?
# 393     ?      1      1                2668  22.3583      ?         C    C
#
#     body      home.dest
# 0     70              ?
# 1      ?              ?
# 2      ?  Cambridge, MA
# 3    131              ?
# 4      ?              ?
# ..   ...            ...
# 389    ?              ?
# 390    ?              ?
# 391   32              ?
# 392    ?              ?
# 393    ?              ?
#
# [394 rows x 24 columns]

# %%
titanic_raw_data = pd.concat([titanic_train, titanic_sample], axis=0)

# %%
titanic_raw_data.to_csv('C:/Users/scien/Videos/titanic/titanic_full_data2.csv', index=False)

# %%
titanic_raw_data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 389         1305         0       3
# 390         1306         1       1
# 391         1307         0       3
# 392         1308         0       3
# 393         1309         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 389                                 Spector, Mr. Woolf    male   NaN      0
# 390                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 391                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 392                                Ware, Mr. Frederick    male   NaN      0
# 393                           Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked
# 0        0           A/5 21171    7.2500   NaN        S
# 1        0            PC 17599   71.2833   C85        C
# 2        0    STON/O2. 3101282    7.9250   NaN        S
# 3        0              113803   53.1000  C123        S
# 4        0              373450    8.0500   NaN        S
# ..     ...                 ...       ...   ...      ...
# 389      0           A.5. 3236    8.0500   NaN        S
# 390      0            PC 17758  108.9000  C105        C
# 391      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 392      0              359309    8.0500   NaN        S
# 393      1                2668   22.3583   NaN        C
#
# [1285 rows x 12 columns]

# %%
titanic_raw_data = pd.read_csv('C:/Users/scien/Videos/titanic/titanic_raw_data.csv')
