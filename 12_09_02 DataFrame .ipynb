# %% [markdown]
# # DataFrame
#
# - csv(comma serperated value) : not an excel file
# - it just text file

# %%
import pandas as pd 
import numpy as np

# %%
path = "./titanic/train.csv"
rawData = pd.read_csv(path)

# %%
rawData 
# pandas의 데이터 프레임 형태
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
rawData.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# ## dataframe의 속성

# %%
# 데이터 파일의 행렬 구조 
rawData.shape
# Out:
# (891, 12)

# %%
# 컬럼별 통계정보 
round(rawData.describe(),2)
# Out:
#        PassengerId  Survived  Pclass     Age   SibSp   Parch    Fare
# count       891.00    891.00  891.00  714.00  891.00  891.00  891.00
# mean        446.00      0.38    2.31   29.70    0.52    0.38   32.20
# std         257.35      0.49    0.84   14.53    1.10    0.81   49.69
# min           1.00      0.00    1.00    0.42    0.00    0.00    0.00
# 25%         223.50      0.00    2.00   20.12    0.00    0.00    7.91
# 50%         446.00      0.00    3.00   28.00    0.00    0.00   14.45
# 75%         668.50      1.00    3.00   38.00    1.00    0.00   31.00
# max         891.00      1.00    3.00   80.00    8.00    6.00  512.33

# %%
# information of rawData 
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
rawData
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
rawData.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.699118
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# dtype: float64

# %%
rawData.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
rawData.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
path = "./titanic/train.csv" # PassengerId를 인덱스로 표현   # 원하는 컬럼만                             #인코딩  #데이터를 나눠서 읽어줌
rawData = pd.read_csv(path, index_col='PassengerId', usecols=['PassengerId', 'Survived', 'Age', 'Name'], encoding='euc-kr', chunksize=10,)
rawData

# %%
# 10개씩 끊어서 불러오기 # 데이터가 커질 때 이용함 
for row in rawData:
    print(row)
# Out:
#              Survived                                               Name   Age
# PassengerId
# 1                   0                            Braund, Mr. Owen Harris  22.0
# 2                   1  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3                   1                             Heikkinen, Miss. Laina  26.0
# 4                   1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5                   0                           Allen, Mr. William Henry  35.0
# 6                   0                                   Moran, Mr. James   NaN
# 7                   0                            McCarthy, Mr. Timothy J  54.0
# 8                   0                     Palsson, Master. Gosta Leonard   2.0
# 9                   1  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  27.0
# 10                  1                Nasser, Mrs. Nicholas (Adele Achem)  14.0
#              Survived                                               Name   Age
# PassengerId
# ...

# %%
path = "./titanic/train.csv" # PassengerId를 인덱스로 표현   # 원하는 컬럼만                             #인코딩  #데이터를 나눠서 읽어줌
rawData = pd.read_csv(path, header=None, names=['first', 'second'], usecols=[1,2])
rawData
# 첫번째 속성값을 그냥 행으로 지정하고 숫자형 속성값을 불러온다
# Out:
#         first  second
# 0    Survived  Pclass
# 1           0       3
# 2           1       1
# 3           1       3
# 4           1       1
# ..        ...     ...
# 887         0       2
# 888         1       1
# 889         0       3
# 890         1       1
# 891         0       3
#
# [892 rows x 2 columns]

# %%
path = "./titanic/train.csv" # PassengerId를 인덱스로 표현   # 원하는 컬럼만                         
                                             #문제 있는건 무시하고 출력 
rawData = pd.read_csv(path, engine='python', error_bad_lines=True, encoding='utf-8')
rawData
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
rawData[['Name', 'Sex', 'Ticket', 'Survived']]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket  Survived
# 0           A/5 21171         0
# 1            PC 17599         1
# 2    STON/O2. 3101282         1
# 3              113803         1
# 4              373450         0
# ...

# %%
type(rawData['Name'])
# Out:
# pandas.core.series.Series

# %%
type(rawData['Name'][0])
# Out:
# str

# %%
print(rawData['Name'])
print(type(rawData['Name']))
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object
# <class 'pandas.core.series.Series'>

# %%
print(rawData[['Name']])
print(type(rawData[['Name']]))
# Out:
#                                                   Name
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# ..                                                 ...
# 886                              Montvila, Rev. Juozas
# 887                       Graham, Miss. Margaret Edith
# 888           Johnston, Miss. Catherine Helen "Carrie"
# 889                              Behr, Mr. Karl Howell
# 890                                Dooley, Mr. Patrick
#
# [891 rows x 1 columns]
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# rawData[''] 값 \
# rawData(['']) 시리즈
# rawData[['']] 데이터 프레임

# %%
rawData.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# 데이터 타입의 형 변환 
rawData['Survived'] =rawData['Survived'].astype(str)

# %%
rawData.dtypes
# Out:
# PassengerId      int64
# Survived        object
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
rawData['Sex'].describe()
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: Sex, dtype: object

# %%
round(rawData['Age'].describe(), 2)
# Out:
# count    714.00
# mean      29.70
# std       14.53
# min        0.42
# 25%       20.12
# 50%       28.00
# 75%       38.00
# max       80.00
# Name: Age, dtype: float64

# %% [markdown]
# # Pandas 데이터 프레임의 선택(인덱싱) 및 조작

# %%
rawData.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1        0       3
# 1            2        1       1
# 2            3        1       3
# 3            4        1       1
# 4            5        0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
rawData.iloc[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
rawData.iloc[[0]]
# Out:
#    PassengerId Survived  Pclass                     Name   Sex   Age  SibSp  \
# 0            1        0       3  Braund, Mr. Owen Harris  male  22.0      1
#
#    Parch     Ticket  Fare Cabin Embarked
# 0      0  A/5 21171  7.25   NaN        S

# %%
rawData.iloc[[-1]]
# Out:
#      PassengerId Survived  Pclass                 Name   Sex   Age  SibSp  \
# 890          891        0       3  Dooley, Mr. Patrick  male  32.0      0
#
#      Parch  Ticket  Fare Cabin Embarked
# 890      0  370376  7.75   NaN        Q

# %%
rawData.iloc[:,0]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
rawData.iloc[:,[2]]
# Out:
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]

# %%
rawData.iloc[:,[-1]]
# Out:
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# 886        S
# 887        S
# 888        S
# 889        C
# 890        Q
#
# [891 rows x 1 columns]

# %%
rawData.iloc[5:10,]
# Out:
#    PassengerId Survived  Pclass  \
# 5            6        0       3
# 6            7        0       1
# 7            8        0       3
# 8            9        1       3
# 9           10        1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 5      0  330877   8.4583   NaN        Q
# 6      0   17463  51.8625   E46        S
# 7      1  349909  21.0750   NaN        S
# 8      2  347742  11.1333   NaN        S
# 9      0  237736  30.0708   NaN        C

# %%
rawData.iloc[:, 0:2]
# Out:
#      PassengerId Survived
# 0              1        0
# 1              2        1
# 2              3        1
# 3              4        1
# 4              5        0
# ..           ...      ...
# 886          887        0
# 887          888        1
# 888          889        0
# 889          890        1
# 890          891        0
#
# [891 rows x 2 columns]

# %%
            #불러올 행 # 불러올 열 
rawData.iloc[2:9, [2,5,8]]
# Out:
#    Pclass   Age            Ticket
# 2       3  26.0  STON/O2. 3101282
# 3       1  35.0            113803
# 4       3  35.0            373450
# 5       3   NaN            330877
# 6       1  54.0             17463
# 7       3   2.0            349909
# 8       3  27.0            347742

# %%
rawData[1:3]
# Out:
#    PassengerId Survived  Pclass  \
# 1            2        1       1
# 2            3        1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
rawData.iloc[3]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                      35
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
rawData.loc[3]
# Out:
# PassengerId                                               4
# Survived                                                  1
# Pclass                                                    1
# Name           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                  female
# Age                                                      35
# SibSp                                                     1
# Parch                                                     0
# Ticket                                               113803
# Fare                                                   53.1
# Cabin                                                  C123
# Embarked                                                  S
# Name: 3, dtype: object

# %%
rawData.loc[[1,3]]
# Out:
#    PassengerId Survived  Pclass  \
# 1            2        1       1
# 3            4        1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch    Ticket     Fare Cabin Embarked
# 1      0  PC 17599  71.2833   C85        C
# 3      0    113803  53.1000  C123        S

# %%
rawData.iloc[[1,3], [1,2,3]]  # iloc은 정수형태로 지정가능
# Out:
#   Survived  Pclass                                               Name
# 1        1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3        1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)

# %%
rawData.loc[[1,3], ['Name', 'Pclass']] # loc은 열 이름으로
# Out:
#                                                 Name  Pclass
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1

# %%
rawData.loc[[1,3], 'Name':'Cabin']
# Out:
#                                                 Name     Sex   Age  SibSp  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch    Ticket     Fare Cabin
# 1      0  PC 17599  71.2833   C85
# 3      0    113803  53.1000  C123

# %% [markdown]
# fancy indexing

# %%
rawData.loc[rawData['Pclass'] == 3]['Cabin']
# Out:
# 0      NaN
# 2      NaN
# 4      NaN
# 5      NaN
# 7      NaN
#       ...
# 882    NaN
# 884    NaN
# 885    NaN
# 888    NaN
# 890    NaN
# Name: Cabin, Length: 491, dtype: object

# %%
rawData.loc[rawData['Sex'] == 'female', ['Survived']]
# Out:
#     Survived
# 1          1
# 2          1
# 3          1
# 8          1
# 9          1
# ..       ...
# 880        1
# 882        0
# 885        0
# 887        1
# 888        0
#
# [314 rows x 1 columns]

# %%
rawData.loc[rawData['Pclass']==1, 'Cabin']
# Out:
# 1              C85
# 3             C123
# 6              E46
# 11            C103
# 23              A6
#           ...
# 871            D35
# 872    B51 B53 B55
# 879            C50
# 887            B42
# 889           C148
# Name: Cabin, Length: 216, dtype: object

# %%
rawData.loc[rawData['Pclass']==1, ['Cabin', 'Survived', 'Age']]
# Out:
#            Cabin Survived   Age
# 1            C85        1  38.0
# 3           C123        1  35.0
# 6            E46        0  54.0
# 11          C103        1  58.0
# 23            A6        1  28.0
# ..           ...      ...   ...
# 871          D35        1  47.0
# 872  B51 B53 B55        0  33.0
# 879          C50        1  56.0
# 887          B42        1  19.0
# 889         C148        1  26.0
#
# [216 rows x 3 columns]

# %%
rawData.loc[rawData['Pclass']==1, 'Name':'Cabin']
# Out:
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin
# ...

# %%
rawData.loc[rawData['Name'].str.endswith('Rose')]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
rawData.loc[rawData['Embarked'].isin(['s', 'Q'])]
# Out:
#      PassengerId Survived  Pclass                                  Name  \
# 5              6        0       3                      Moran, Mr. James
# 16            17        0       3                  Rice, Master. Eugene
# 22            23        1       3           McGowan, Miss. Anna "Annie"
# 28            29        1       3         O'Dwyer, Miss. Ellen "Nellie"
# 32            33        1       3              Glynn, Miss. Mary Agatha
# ..           ...      ...     ...                                   ...
# 790          791        0       3              Keane, Mr. Andrew "Andy"
# 825          826        0       3                       Flynn, Mr. John
# 828          829        1       3          McCormack, Mr. Thomas Joseph
# 885          886        0       3  Rice, Mrs. William (Margaret Norton)
# 890          891        0       3                   Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# ...

# %%
rawData.loc[(rawData['Sex'] == 'female') & (rawData['Survived'] == '1'), ['Cabin', 'Pclass']]
# Out:
#     Cabin  Pclass
# 1     C85       1
# 2     NaN       3
# 3    C123       1
# 8     NaN       3
# 9     NaN       2
# ..    ...     ...
# 874   NaN       2
# 875   NaN       3
# 879   C50       1
# 880   NaN       2
# 887   B42       1
#
# [233 rows x 2 columns]

# %%
rawData.loc[(rawData['Sex'] == 'male') & (rawData['Survived'] == '0')].count()
# Out:
# PassengerId    468
# Survived       468
# Pclass         468
# Name           468
# Sex            468
# Age            360
# SibSp          468
# Parch          468
# Ticket         468
# Fare           468
# Cabin           62
# Embarked       468
# dtype: int64

# %%
                                           # NaN을 찾는 것  
rawData.loc[rawData['Pclass']==3, 'Cabin'].isna().sum()
# Out:
# 479

# %%
rawData.loc[(rawData['PassengerId']==1), 'Pclass'].value_counts()
# Out:
# 3    1
# Name: Pclass, dtype: int64

# %%
                            #커스텀 함수
boolIdx = rawData['Name'].apply(lambda x: len(x. split()) == 5)

# %%
boolIdx
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888     True
# 889    False
# 890    False
# Name: Name, Length: 891, dtype: bool

# %%
# 블리언 인덱싱
rawData.loc[boolIdx]
# Out:
#      PassengerId Survived  Pclass  \
# 9             10        1       2
# 14            15        0       3
# 15            16        1       2
# 38            39        0       3
# 49            50        0       3
# ..           ...      ...     ...
# 867          868        0       1
# 874          875        1       2
# 875          876        1       3
# 885          886        0       3
# 888          889        0       3
#
#                                               Name     Sex   Age  SibSp  \
# 9              Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 14            Vestrom, Miss. Hulda Amanda Adolfina  female  14.0      0
# 15                Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# 38              Vander Planke, Miss. Augusta Maria  female  18.0      2
# 49   Arnold-Franchi, Mrs. Josef (Josefine Franchi)  female  18.0      1
# ..                                             ...     ...   ...    ...
# ...

# %%
rawData['Survived'] = rawData['Survived'].astype(np.int64)

# %%
rawData['Survived'].sum()
# Out:
# 342

# %%
rawData['Age'].mean()
# Out:
# 29.69911764705882

# %%
rawData['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
rawData['Cabin'].count()
# Out:
# 204

# %%
rawData['Cabin'].isna().sum()
# Out:
# 687

# %%
rawData['Age'].isna().sum()
# Out:
# 177

# %%
                # 결측치를 0으로 채워넣음
rawData['Age'].fillna(0)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     0.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
                      # 열을 기준으로 삭제   #inplace는 ㄹㅇ로 삭제
rawData.drop('Cabin', axis = 1, inplace=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
rawData.drop(columns='Ticket')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
rawData.drop(axis=1)
# Out:
#      PassengerId  Survived  Pclass  \
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                        Allen, Mr. William Henry    male  35.0      0      0
# 5                                Moran, Mr. James    male   NaN      0      0
# 6                         McCarthy, Mr. Timothy J    male  54.0      0      0
# 7                  Palsson, Master. Gosta Leonard    male   2.0      3      1
# ...

# %%
rawData.iloc[0:10,].drop(1)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# ...

# %%
rawData.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
rawData.rename(columns={ 'Sex' : 'Gender'})
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
rawData.rename(columns=lambda x: x.upper())
# Out:
#      PASSENGERID  SURVIVED  PCLASS  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   NAME     SEX   AGE  SIBSP  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
        #그룹화한다 #속성값으로 
rawData.groupby(['Sex'])['Survived'].sum()
# Out:
# Sex
# female    233
# male      109
# Name: Survived, dtype: int64

# %%
rawData.groupby(['Pclass'])['Survived'].count()
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Survived, dtype: int64

# %%
rawData.groupby(['Pclass','Survived']).group
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-317-243dd6233037> in <module>
# ----> 1 rawData.groupby(['Pclass','Survived']).group
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     578             return self[attr]
#     579
# --> 580         raise AttributeError(
#     581             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     582         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'group'

# %%
rawData.groupby(['Pclass','Survived']).count()
# Out:
#                  PassengerId  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Pclass Survived
# 1      0                  80    80   80   64     80     80      80    80
#        1                 136   136  136  122    136    136     136   136
# 2      0                  97    97   97   90     97     97      97    97
#        1                  87    87   87   83     87     87      87    87
# 3      0                 372   372  372  270    372    372     372   372
#        1                 119   119  119   85    119    119     119   119
#
#                  Cabin  Embarked
# Pclass Survived
# 1      0            59        80
#        1           117       134
# 2      0             3        97
#        1            13        87
# 3      0             6       372
#        1             6       119

# %%
rawData
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
rawData.groupby(['Pclass','Survived']).agg({'PassangerId':'count', 'Age':'sum'})
# Out:
# ---------------------------------------------------------------------------
# SpecificationError                        Traceback (most recent call last)
# <ipython-input-321-36aeefdb415e> in <module>
# ----> 1 rawData.groupby(['Pclass','Survived']).agg({'PassangerId':'count', 'Age':'sum'})
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     926         func = _maybe_mangle_lambdas(func)
#     927
# --> 928         result, how = self._aggregate(func, *args, **kwargs)
#     929         if how is None:
#     930             return result
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in _aggregate(self, arg, *args, **kwargs)
#     355                     obj.columns.intersection(keys)
#     356                 ) != len(keys):
# --> 357                     raise SpecificationError("nested renamer is not supported")
#     358
#     359             from pandas.core.reshape.concat import concat
#
# ...

# %%
user_usage = pd.read_csv('https://raw.githubusercontent.com/shanealynn/Pandas-Merge-Tutorial/master/user_usage.csv')
user_device = pd.read_csv('https://raw.githubusercontent.com/shanealynn/Pandas-Merge-Tutorial/master/user_device.csv')
device = pd.read_csv('https://raw.githubusercontent.com/shanealynn/Pandas-Merge-Tutorial/master/android_devices.csv')

# %%
user_usage.head(n=2)
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788

# %%
user_usage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   outgoing_mins_per_month  240 non-null    float64
#  1   outgoing_sms_per_month   240 non-null    float64
#  2   monthly_mb               240 non-null    float64
#  3   use_id                   240 non-null    int64
# dtypes: float64(3), int64(1)
# memory usage: 7.6 KB

# %%
user_device.head(n=2)
# Out:
#    use_id  user_id platform  platform_version     device  use_type_id
# 0   22782    26980      ios              10.2  iPhone7,2            2
# 1   22783    29628  android               6.0    Nexus 5            3

# %%
user_device.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 272 entries, 0 to 271
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   use_id            272 non-null    int64
#  1   user_id           272 non-null    int64
#  2   platform          272 non-null    object
#  3   platform_version  272 non-null    float64
#  4   device            272 non-null    object
#  5   use_type_id       272 non-null    int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 12.9+ KB

# %% [markdown]
# 겹치는 부분이 있을 경우 두 데이터를 하나로 합칠 수 있다

# %%
device.head(n=2)
# Out:
#   Retail Branding Marketing Name  Device                      Model
# 0             NaN            NaN  AD681H  Smartfren Andromax AD681H
# 1             NaN            NaN   FJL21                      FJL21

# %%
#inner_join 
                                                    # 엑셀의 기본키 
result = pd.merge(left=user_usage, right=user_device, on='use_id')
result.head() # on을 기준으로 왼쪽 표 오른쪽 표로 나뉨
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0    12921  android               4.3  GT-I9505            1
# 1    28714  android               6.0  SM-G930F            1
# 2    28714  android               6.0  SM-G930F            1
# 3    29592  android               5.1     D2303            1
# 4    28217  android               5.1  SM-G361F            1

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 159 entries, 0 to 158
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   outgoing_mins_per_month  159 non-null    float64
#  1   outgoing_sms_per_month   159 non-null    float64
#  2   monthly_mb               159 non-null    float64
#  3   use_id                   159 non-null    int64
#  4   user_id                  159 non-null    int64
#  5   platform                 159 non-null    object
#  6   platform_version         159 non-null    float64
#  7   device                   159 non-null    object
#  8   use_type_id              159 non-null    int64
# dtypes: float64(4), int64(3), object(2)
# memory usage: 12.4+ KB

# %%
#left_join 
                                                    # 엑셀의 기본키 
result = pd.merge(left=user_usage, right=user_device, on='use_id', how='left')
result.head() # on을 기준으로 왼쪽 표 오른쪽 표로 나뉨
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0  12921.0  android               4.3  GT-I9505          1.0
# 1  28714.0  android               6.0  SM-G930F          1.0
# 2  28714.0  android               6.0  SM-G930F          1.0
# 3  29592.0  android               5.1     D2303          1.0
# 4  28217.0  android               5.1  SM-G361F          1.0

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 0 to 239
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   outgoing_mins_per_month  240 non-null    float64
#  1   outgoing_sms_per_month   240 non-null    float64
#  2   monthly_mb               240 non-null    float64
#  3   use_id                   240 non-null    int64
#  4   user_id                  159 non-null    float64
#  5   platform                 159 non-null    object
#  6   platform_version         159 non-null    float64
#  7   device                   159 non-null    object
#  8   use_type_id              159 non-null    float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 18.8+ KB

# %%
#right_join 
                                                    # 엑셀의 기본키 
result = pd.merge(left=user_usage, right=user_device, on='use_id', how='right')
result.head() # on을 기준으로 왼쪽 표 오른쪽 표로 나뉨
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0    12921  android               4.3  GT-I9505            1
# 1    28714  android               6.0  SM-G930F            1
# 2    28714  android               6.0  SM-G930F            1
# 3    29592  android               5.1     D2303            1
# 4    28217  android               5.1  SM-G361F            1

# %%
#outer_join 
                                                    # 엑셀의 기본키 
result = pd.merge(left=user_usage, right=user_device, on='use_id', how='outer')
result.head() # on을 기준으로 왼쪽 표 오른쪽 표로 나뉨
# Out:
#    outgoing_mins_per_month  outgoing_sms_per_month  monthly_mb  use_id  \
# 0                    21.97                    4.82     1557.33   22787
# 1                  1710.08                  136.88     7267.55   22788
# 2                  1710.08                  136.88     7267.55   22789
# 3                    94.46                   35.17      519.12   22790
# 4                    71.59                   79.26     1557.33   22792
#
#    user_id platform  platform_version    device  use_type_id
# 0  12921.0  android               4.3  GT-I9505          1.0
# 1  28714.0  android               6.0  SM-G930F          1.0
# 2  28714.0  android               6.0  SM-G930F          1.0
# 3  29592.0  android               5.1     D2303          1.0
# 4  28217.0  android               5.1  SM-G361F          1.0

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353 entries, 0 to 352
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   outgoing_mins_per_month  240 non-null    float64
#  1   outgoing_sms_per_month   240 non-null    float64
#  2   monthly_mb               240 non-null    float64
#  3   use_id                   353 non-null    int64
#  4   user_id                  272 non-null    float64
#  5   platform                 272 non-null    object
#  6   platform_version         272 non-null    float64
#  7   device                   272 non-null    object
#  8   use_type_id              272 non-null    float64
# dtypes: float64(6), int64(1), object(2)
# memory usage: 27.6+ KB
